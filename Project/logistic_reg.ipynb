# %% [markdown]
# # Logistic Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={
    "age":[24,50,70,18,30,46,44,22,60,47],
    "insurance":[0,1,1,0,0,1,1,1,0,1]
}
df=pd.DataFrame(data)
x=df['age']
y=df['insurance']
df
# Out:
#    age  insurance
# 0   24          0
# 1   50          1
# 2   70          1
# 3   18          0
# 4   30          0
# 5   46          1
# 6   44          1
# 7   22          1
# 8   60          0
# 9   47          1

# %%
plt.scatter(df.age,df.insurance,color='blue',marker='*')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
X_train
# Out:
# 7    22
# 5    46
# 3    18
# 8    60
# 2    70
# 9    47
# 6    44
# 4    30
# Name: age, dtype: int64

# %%
X_test
# Out:
# 1    50
# 0    24
# Name: age, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# %%
model=LogisticRegression()

# %%
x=np.array(X_train).reshape(-1, 1)
x
# Out:
# array([[22],
#        [46],
#        [18],
#        [60],
#        [70],
#        [47],
#        [44],
#        [30]])

# %%
y=np.array(y_train)
y
# Out:
# array([1, 1, 0, 0, 1, 1, 1, 0])

# %%
model.fit(x,y)
# Out:
# LogisticRegression()

# %%
xi=np.array(X_test).reshape(-1, 1)
model.predict(xi)
# Out:
# array([1, 0])
